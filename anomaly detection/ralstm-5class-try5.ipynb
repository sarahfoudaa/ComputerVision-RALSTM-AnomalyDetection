# %% [markdown]
# # libraries

# %%
import os
import pandas as pd
import numpy as np
from keras import backend as K

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array

from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense , Input,Lambda
from tensorflow.keras.layers import Conv2D, TimeDistributed, MaxPooling2D, Flatten, Dense,GlobalAveragePooling1D,GlobalAveragePooling2D
from tensorflow.keras.layers import Reshape
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau , EarlyStopping
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from tensorflow.keras.layers import LSTM, Lambda, Dense, Permute, Multiply, RepeatVector, Activation, add, Conv2D, GlobalAveragePooling2D

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # data preparation

# %%
fullpath = '/kaggle/input/crimeucfdataset/'
os.listdir(fullpath)
# Out:
# ['anomaly', 'Anomaly_Dataset']

# %%
p = os.path.join(fullpath,'Anomaly_Dataset')

# %%
p1 = os.path.join(p,'Anomaly_Videos')
new_path=[]
for i in os.listdir(p1):
    if i[-3:] =='txt':
        pass
    else:
        new_path.append(i)

# %%
new_path
# Out:
# ['Anomaly-Videos-Part-2', 'Anomaly-Videos-Part-1', 'Normal-Videos-Part-1']

# %%
p_an1 = os.path.join(p1,new_path[0])
p_an2 = os.path.join(p1,new_path[1])
p_no = os.path.join(p1,new_path[2])

# %%
p_an2
# Out:
# '/kaggle/input/crimeucfdataset/Anomaly_Dataset/Anomaly_Videos/Anomaly-Videos-Part-1'

# %%
import os
import glob
import pandas as pd

# Set the directory paths and class names
dir_path_1 = p_an1
dir_path_2 = p_an2
class_names_1 = [ "Explosion","Fighting"]
class_names_2 = ["Abuse","Assault"]

# Initialize empty lists for the video paths and labels
video_paths = []
labels = []

# Iterate over the first directory and class names to retrieve the video paths and labels
for class_name in class_names_1:
    # Get the path to the class subdirectory
    class_dir_path = os.path.join(dir_path_1, class_name)
    
    # Get a list of file paths in the class subdirectory
    file_paths = glob.glob(os.path.join(class_dir_path, "*.mp4"))
    
    # Append the file paths and class label to the lists
    video_paths.extend(file_paths)
    labels.extend([class_name] * len(file_paths))

# Iterate over the second directory and class names to retrieve the video paths and labels
for class_name in class_names_2:
    # Get the path to the class subdirectory
    class_dir_path = os.path.join(dir_path_2, class_name)
    
    # Get a list of file paths in the class subdirectory
    file_paths = glob.glob(os.path.join(class_dir_path, "*.mp4"))
    
    # Append the file paths and class label to the lists
    video_paths.extend(file_paths)
    labels.extend([class_name] * len(file_paths))

# Create a dataframe with the video paths and labels
df = pd.DataFrame({"video_path": video_paths, "label": labels})

# Print the dataframe
print(df)
# Out:
#                                             video_path      label
# 0    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 1    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 2    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 3    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 4    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# ..                                                 ...        ...
# 195  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 196  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 197  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 198  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 199  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
#
# [200 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# Explosion    50
# Fighting     50
# Abuse        50
# Assault      50
# Name: label, dtype: int64

# %%
df = df.drop(index=df.iloc[:100].sample(n=50).index)
df
# Out:
#                                             video_path      label
# 1    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 2    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 5    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 6    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 7    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# ..                                                 ...        ...
# 195  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 196  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 197  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 198  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 199  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
#
# [150 rows x 2 columns]

# %%
video_paths = []
labels = []

# Get a list of file paths in the class subdirectory
file_paths = glob.glob(os.path.join(p_no, "*.mp4"))

# Append the file paths and class label to the lists
video_paths.extend(file_paths)
labels.extend(['Normal'] * len(file_paths))
# Create a new dataframe with the new video paths and labels
df_new = pd.DataFrame({"video_path": video_paths, "label": labels})

# %%
df_new
# Out:
#                                             video_path   label
# 0    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 1    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 2    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 3    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 4    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# ..                                                 ...     ...
# 145  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 146  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 147  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 148  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 149  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
#
# [150 rows x 2 columns]

# %%
df_new = df_new.drop(index=df_new.sample(n=100).index)
df_new
# Out:
#                                             video_path   label
# 1    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 4    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 7    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 10   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 26   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 30   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 31   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 32   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 36   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 41   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 45   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 51   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 52   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 56   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 59   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 62   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 68   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 70   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 71   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 72   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 73   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 75   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 78   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 80   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 81   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 85   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 90   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 91   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 92   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 93   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 95   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 96   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 97   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 98   /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 102  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 104  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 106  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 111  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 112  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 113  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 118  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 121  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 122  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 126  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 129  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 131  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 133  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 141  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 144  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal
# 147  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Normal

# %%
All_Data =  pd.concat([df, df_new], ignore_index=True)
All_Data
# Out:
#                                             video_path      label
# 0    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 1    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 2    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 3    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 4    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# ..                                                 ...        ...
# 195  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...     Normal
# 196  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...     Normal
# 197  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...     Normal
# 198  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...     Normal
# 199  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...     Normal
#
# [200 rows x 2 columns]

# %%
df_shuffled = All_Data.sample(frac=1.0, random_state=42)
df_shuffled = df_shuffled.reset_index(drop=True)
df_shuffled
# Out:
#                                             video_path      label
# 0    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      Abuse
# 1    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 2    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 3    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...     Normal
# 4    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# ..                                                 ...        ...
# 195  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
# 196  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...  Explosion
# 197  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      Abuse
# 198  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...     Normal
# 199  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...    Assault
#
# [200 rows x 2 columns]

# %%
label_map = {'Normal': 0, 'Abuse': 1, 'Assault': 2, 'Explosion': 3, 'Fighting': 4}
df_shuffled['label'] = df_shuffled['label'].map(label_map)

# %%
df_shuffled
# Out:
#                                             video_path  label
# 0    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      1
# 1    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      3
# 2    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      3
# 3    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      0
# 4    /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      2
# ..                                                 ...    ...
# 195  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      2
# 196  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      3
# 197  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      1
# 198  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      0
# 199  /kaggle/input/crimeucfdataset/Anomaly_Dataset/...      2
#
# [200 rows x 2 columns]

# %%
# split data to train and val
from sklearn.model_selection import train_test_split

# Split the dataframe into training and testing sets
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
len(train_df)
# Out:
# 160

# %%
len(val_df)
# Out:
# 40

# %%
# Split the data into training, validation, and test sets
X_train , y_train, X_val, y_val = train_df['video_path'].tolist() , train_df['label'].tolist(),val_df['video_path'].tolist() , val_df['label'].tolist()

# %% [markdown]
# # Generator

# %%
# %%writefile mod_gen33.py
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
import tensorflow as tf

class VideoDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, video_paths, labels, batch_size=32, frame_size=(224, 224), num_channels=3, num_classes=5, shuffle=True, num_frames=30):
        self.video_paths = video_paths
        self.labels = labels
        self.batch_size = batch_size
        self.frame_size = frame_size
        self.num_channels = num_channels
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.num_frames = num_frames
        self.indexes = np.arange(len(self.video_paths))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.video_paths) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        video_paths_batch = [self.video_paths[k] for k in indexes]
        labels_batch = [self.labels[k] for k in indexes]
        X, y = self.__data_generation(video_paths_batch, labels_batch)
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, video_paths_batch, labels_batch):
        X = np.zeros((self.batch_size, self.num_frames, *self.frame_size, self.num_channels))
        y = np.zeros((self.batch_size, self.num_classes))
        #print('labels_batch:', labels_batch)
        #print('num_classes:', self.num_classes)
        for i, video_path in enumerate(video_paths_batch):
            frames = self.get_frames(video_path)
      
            clip = np.concatenate(frames, axis=-1)  # concatenate RGB channels
          
            clip_shape = clip.shape
            clip = clip.transpose((1, 2, 3, 0))
            X[i,:,:,:,:] = clip
            #print(X)
            y[i,] = to_categorical(labels_batch[i], num_classes=self.num_classes)
        return X, y

    def get_frames(self, video_path):
        mean = [0.22146088 , 0.20873131  ,0.2019145 ]
        std =  [0.52410259  ,0.52200656  ,0.52084839]
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            cap.open(video_path)
          # Get the total number of frames
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
      #print("total_frames:",total_frames)
      # Calculate the time interval between frames
        time_interval = total_frames / 3 / self.num_frames
      #print("time_interval:",time_interval)
        clips=[]
       # Sample frames at a fixed time interval
        frames = []
        for i in range(self.num_frames):
        # Calculate the frame index based on the time interval
            frame_index = int(i * time_interval)

        # Seek to the frame index using cv2.CAP_PROP_POS_FRAMES
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_index)
            ret = True
            if (True and ret):
              # Read and decode the frame
                ret, frame = cap.read()

              # Append the frame to the list of frames
                if ret==False:
                        break

                frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
                frame = (frame - mean) / std
                frames.append(frame)
        avg_resized_frames = []
        r_frames = []
        g_frames = []
        b_frames = []
        for af in frames:
            rsz_f = cv2.resize(af, (self.frame_size[0], self.frame_size[1]))
            r_frames.append(rsz_f[:,:,0])
            g_frames.append(rsz_f[:,:,1])
            b_frames.append(rsz_f[:,:,2])

        avg_resized_frames.append(r_frames)
        avg_resized_frames.append(g_frames)
        avg_resized_frames.append(b_frames)

        clip=np.asarray(avg_resized_frames)

        clips.append(clip)
        return clips
# Out:
# Writing mod_gen33.py

# %%
from mod_gen33 import VideoDataGenerator

# %%
# def __init__(self, video_paths, labels, batch_size, frame_size=(224, 224), num_channels=3, num_classes=2, shuffle=True, num_frames=16):

train_generator = VideoDataGenerator(X_train, y_train, batch_size=32, frame_size=(224, 224), num_channels=3, num_classes=5, shuffle=False, num_frames=50)
val_generator = VideoDataGenerator(X_val, y_val, batch_size=32, frame_size=(224, 224), num_channels=3, num_classes=5, shuffle=False, num_frames=50)

# %%
X_batch, y_batch = train_generator[0]

# %%
X_batch.shape
# Out:
# (32, 50, 224, 224, 3)

# %%
X_batch[0][0][0][0]
# Out:
# array([-0.42255254, -0.39986338, -0.38766463])

# %%
y_batch.shape
# Out:
# (32, 5)

# %%
import matplotlib.pyplot as plt
# print the all 16 frames for first video
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10))

t = X_batch[0]
for i, ax in enumerate(axes.flat):
    # Get the i-th frame tensor and convert it to a numpy array
    frame_tensor = t[i, :, :, :] /255 # shape = (3,112,112)  # loop on frame?? 16
    #print(frame_tensor.shape)
    # Plot the frame using imshow
    ax.imshow(frame_tensor)  #  shape transpose
    ax.set_axis_off()

plt.show()

# %% [markdown]
# # build model

# %%
from keras.layers import LSTM, Lambda, Dense, Permute, Multiply, RepeatVector, Activation

def attention_block(inputs):
    """
    Compute attention scores and apply them to the input tensor.
    """
    input_dim = int(inputs.shape[2])
    a = Permute((2, 1))(inputs)  # convert (batch_size, timesteps, input_dim) to (batch_size, input_dim, timesteps)
    a = Dense(inputs.shape[1], activation='softmax')(a)  # compute attention scores
    a = Permute((2, 1))(a)  # convert (batch_size, input_dim, timesteps) back to (batch_size, timesteps, input_dim)
    a = Multiply()([inputs, a])  # apply attention scores to input tensor
    return a

def make_residual_lstm_layers(input, rnn_width, rnn_depth, rnn_dropout, num_classes):
    """
    The intermediate LSTM layers return sequences, while the last returns a single element.
    The input is also a sequence. In order to match the shape of input and output of the LSTM
    to sum them we can do it only for all layers but the last.
    """
    x = input
    for i in range(rnn_depth):
        return_sequences = i < rnn_depth - 1
        x_rnn = LSTM(rnn_width, recurrent_dropout=rnn_dropout, dropout=rnn_dropout, return_sequences=return_sequences)(x)
        if return_sequences:
            x_rnn = attention_block(x_rnn)  # add attention layer
            # Intermediate layers return sequences, input is also a sequence.
            if i > 0 or input.shape[-1] == rnn_width:
                x = add([x, x_rnn])
            else:
                # Note that the input size and RNN output has to match, due to the sum operation.
                # If we want different rnn_width, we'd have to perform the sum from layer 2 on.
                x = x_rnn
        else:
            # Last layer does not return sequences, just the last element
            # so we select only the last element of the previous output.
            def slice_last(x):
                return x[..., -1, :]
            x = add([Lambda(slice_last)(x), x_rnn])
    
    # Add a Dense layer for multi-class classification
    x = Dense(num_classes, activation='softmax')(x)
    
    return x

# %%
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from tensorflow.keras.layers import LSTM, Lambda, Dense, Permute, Multiply, RepeatVector, Activation, add, Conv2D, GlobalAveragePooling2D
def buildRALSTM(rnn_width = 64, rnn_depth = 4, rnn_dropout = 0.5, num_classes = 8,num_frames=16):

    # create input layer for sequence of frames
    frames_input = Input(shape=(num_frames, 224, 224, 3))

    # create MobileNetV2 model without the final classification layers
    mobilenet_model = MobileNetV2(weights='imagenet', include_top=False, pooling='avg')

    # set all layers in the pre-trained MobileNetV2 model to non-trainable
    for layer in mobilenet_model.layers:
        layer.trainable = False

    # get the output from the pre-trained MobileNetV2 model for each frame
    frames_output = []
    for i in range(num_frames):
        frame = frames_input[:, i, :, :, :]
        frame_output = mobilenet_model(frame)
        frames_output.append(frame_output)
    #print(len(frames_output))
    #print(frames_output)
    # concatenate the output from each frame
    aggregated_output = tf.concat(frames_output, axis=0)
    #print(aggregated_output.shape)

    # reshape the output to have a shape of (1, 1, 1280)
    aggregated_output = Reshape((1, 1, 1280))(aggregated_output)    
    #print(aggregated_output.shape)

    # apply a convolutional layer to the aggregated output
    aggregated_output = Conv2D(filters=1280, kernel_size=1, activation='relu')(aggregated_output)
    # reshape the output using a Lambda layer
    aggregated_output = Lambda(lambda x: K.reshape(x, (-1, num_frames, 1280)))(aggregated_output)

    # apply a fully connected layer with 1000 units
    aggregated_output = Dense(units=1000, activation='relu')(aggregated_output)
    #print(aggregated_output.shape)
    x = aggregated_output
    # Add residual LSTM layers with attention blocks
    for i in range(rnn_depth):
        return_sequences = i < rnn_depth - 1
        x_rnn = LSTM(rnn_width, recurrent_dropout=rnn_dropout, dropout=rnn_dropout, return_sequences=return_sequences)(x)
        if return_sequences:
            x_rnn = attention_block(x_rnn)  # add attention layer
            if i > 0 or x.shape[-1] == rnn_width:
                x = add([x, x_rnn])
            else:
                x = x_rnn
        else:
            def slice_last(x):
                return x[..., -1, :]
            x = add([Lambda(slice_last)(x), x_rnn])

    # Add a Dense layer for multi-class classification
    output = Dense(num_classes, activation='softmax')(x)

    # Build the model
    model = tf.keras.models.Model(inputs=frames_input, outputs=output)
    return model

# %%
model = buildRALSTM(rnn_width = 64, rnn_depth = 6, rnn_dropout = 0.2, num_classes = 5,num_frames=50)

# %%
 model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 50, 224, 22  0           []
#                                 4, 3)]
#
#  tf.__operators__.getitem_30 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_31 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_32 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_33 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_34 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_35 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_36 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_37 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_38 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_39 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_40 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_41 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_42 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_43 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_44 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_45 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_46 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_47 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_48 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_49 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_50 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_51 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_52 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_53 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_54 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_55 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_56 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_57 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_58 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_59 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_60 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_61 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_62 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_63 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_64 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_65 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_66 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_67 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_68 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_69 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_70 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_71 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_72 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_73 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_74 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_75 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_76 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_77 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_78 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_79 (S  (None, 224, 224, 3)  0          ['input_3[0][0]']
#  licingOpLambda)
#
#  mobilenetv2_1.00_224 (Function  (None, 1280)        2257984     ['tf.__operators__.getitem_30[0][
#  al)                                                             0]',
#                                                                   'tf.__operators__.getitem_31[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_32[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_33[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_34[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_35[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_36[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_37[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_38[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_39[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_40[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_41[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_42[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_43[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_44[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_45[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_46[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_47[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_48[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_49[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_50[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_51[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_52[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_53[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_54[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_55[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_56[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_57[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_58[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_59[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_60[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_61[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_62[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_63[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_64[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_65[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_66[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_67[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_68[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_69[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_70[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_71[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_72[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_73[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_74[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_75[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_76[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_77[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_78[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_79[0][
#                                                                  0]']
#
#  tf.concat_1 (TFOpLambda)       (None, 1280)         0           ['mobilenetv2_1.00_224[0][0]',
#                                                                   'mobilenetv2_1.00_224[1][0]',
#                                                                   'mobilenetv2_1.00_224[2][0]',
#                                                                   'mobilenetv2_1.00_224[3][0]',
#                                                                   'mobilenetv2_1.00_224[4][0]',
#                                                                   'mobilenetv2_1.00_224[5][0]',
#                                                                   'mobilenetv2_1.00_224[6][0]',
#                                                                   'mobilenetv2_1.00_224[7][0]',
#                                                                   'mobilenetv2_1.00_224[8][0]',
#                                                                   'mobilenetv2_1.00_224[9][0]',
#                                                                   'mobilenetv2_1.00_224[10][0]',
#                                                                   'mobilenetv2_1.00_224[11][0]',
#                                                                   'mobilenetv2_1.00_224[12][0]',
#                                                                   'mobilenetv2_1.00_224[13][0]',
#                                                                   'mobilenetv2_1.00_224[14][0]',
#                                                                   'mobilenetv2_1.00_224[15][0]',
#                                                                   'mobilenetv2_1.00_224[16][0]',
#                                                                   'mobilenetv2_1.00_224[17][0]',
#                                                                   'mobilenetv2_1.00_224[18][0]',
#                                                                   'mobilenetv2_1.00_224[19][0]',
#                                                                   'mobilenetv2_1.00_224[20][0]',
#                                                                   'mobilenetv2_1.00_224[21][0]',
#                                                                   'mobilenetv2_1.00_224[22][0]',
#                                                                   'mobilenetv2_1.00_224[23][0]',
#                                                                   'mobilenetv2_1.00_224[24][0]',
#                                                                   'mobilenetv2_1.00_224[25][0]',
#                                                                   'mobilenetv2_1.00_224[26][0]',
#                                                                   'mobilenetv2_1.00_224[27][0]',
#                                                                   'mobilenetv2_1.00_224[28][0]',
#                                                                   'mobilenetv2_1.00_224[29][0]',
#                                                                   'mobilenetv2_1.00_224[30][0]',
#                                                                   'mobilenetv2_1.00_224[31][0]',
#                                                                   'mobilenetv2_1.00_224[32][0]',
#                                                                   'mobilenetv2_1.00_224[33][0]',
#                                                                   'mobilenetv2_1.00_224[34][0]',
#                                                                   'mobilenetv2_1.00_224[35][0]',
#                                                                   'mobilenetv2_1.00_224[36][0]',
#                                                                   'mobilenetv2_1.00_224[37][0]',
#                                                                   'mobilenetv2_1.00_224[38][0]',
#                                                                   'mobilenetv2_1.00_224[39][0]',
#                                                                   'mobilenetv2_1.00_224[40][0]',
#                                                                   'mobilenetv2_1.00_224[41][0]',
#                                                                   'mobilenetv2_1.00_224[42][0]',
#                                                                   'mobilenetv2_1.00_224[43][0]',
#                                                                   'mobilenetv2_1.00_224[44][0]',
#                                                                   'mobilenetv2_1.00_224[45][0]',
#                                                                   'mobilenetv2_1.00_224[46][0]',
#                                                                   'mobilenetv2_1.00_224[47][0]',
#                                                                   'mobilenetv2_1.00_224[48][0]',
#                                                                   'mobilenetv2_1.00_224[49][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 1280)   0           ['tf.concat_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 1, 1, 1280)   1639680     ['reshape_1[0][0]']
#
#  lambda_2 (Lambda)              (None, 50, 1280)     0           ['conv2d_1[0][0]']
#
#  dense_7 (Dense)                (None, 50, 1024)     1311744     ['lambda_2[0][0]']
#
#  lstm_6 (LSTM)                  (None, 50, 64)       278784      ['dense_7[0][0]']
#
#  permute_10 (Permute)           (None, 64, 50)       0           ['lstm_6[0][0]']
#
#  dense_8 (Dense)                (None, 64, 50)       2550        ['permute_10[0][0]']
#
#  permute_11 (Permute)           (None, 50, 64)       0           ['dense_8[0][0]']
#
#  multiply_5 (Multiply)          (None, 50, 64)       0           ['lstm_6[0][0]',
#                                                                   'permute_11[0][0]']
#
#  lstm_7 (LSTM)                  (None, 50, 64)       33024       ['multiply_5[0][0]']
#
#  permute_12 (Permute)           (None, 64, 50)       0           ['lstm_7[0][0]']
#
#  dense_9 (Dense)                (None, 64, 50)       2550        ['permute_12[0][0]']
#
#  permute_13 (Permute)           (None, 50, 64)       0           ['dense_9[0][0]']
#
#  multiply_6 (Multiply)          (None, 50, 64)       0           ['lstm_7[0][0]',
#                                                                   'permute_13[0][0]']
#
#  add_5 (Add)                    (None, 50, 64)       0           ['multiply_5[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  lstm_8 (LSTM)                  (None, 50, 64)       33024       ['add_5[0][0]']
#
#  permute_14 (Permute)           (None, 64, 50)       0           ['lstm_8[0][0]']
#
#  dense_10 (Dense)               (None, 64, 50)       2550        ['permute_14[0][0]']
#
#  permute_15 (Permute)           (None, 50, 64)       0           ['dense_10[0][0]']
#
#  multiply_7 (Multiply)          (None, 50, 64)       0           ['lstm_8[0][0]',
#                                                                   'permute_15[0][0]']
#
#  add_6 (Add)                    (None, 50, 64)       0           ['add_5[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  lstm_9 (LSTM)                  (None, 50, 64)       33024       ['add_6[0][0]']
#
#  permute_16 (Permute)           (None, 64, 50)       0           ['lstm_9[0][0]']
#
#  dense_11 (Dense)               (None, 64, 50)       2550        ['permute_16[0][0]']
#
#  permute_17 (Permute)           (None, 50, 64)       0           ['dense_11[0][0]']
#
#  multiply_8 (Multiply)          (None, 50, 64)       0           ['lstm_9[0][0]',
#                                                                   'permute_17[0][0]']
#
#  add_7 (Add)                    (None, 50, 64)       0           ['add_6[0][0]',
#                                                                   'multiply_8[0][0]']
#
#  lstm_10 (LSTM)                 (None, 50, 64)       33024       ['add_7[0][0]']
#
#  permute_18 (Permute)           (None, 64, 50)       0           ['lstm_10[0][0]']
#
#  dense_12 (Dense)               (None, 64, 50)       2550        ['permute_18[0][0]']
#
#  permute_19 (Permute)           (None, 50, 64)       0           ['dense_12[0][0]']
#
#  multiply_9 (Multiply)          (None, 50, 64)       0           ['lstm_10[0][0]',
#                                                                   'permute_19[0][0]']
#
#  add_8 (Add)                    (None, 50, 64)       0           ['add_7[0][0]',
#                                                                   'multiply_9[0][0]']
#
#  lambda_3 (Lambda)              (None, 64)           0           ['add_8[0][0]']
#
#  lstm_11 (LSTM)                 (None, 64)           33024       ['add_8[0][0]']
#
#  add_9 (Add)                    (None, 64)           0           ['lambda_3[0][0]',
#                                                                   'lstm_11[0][0]']
#
#  dense_13 (Dense)               (None, 5)            325         ['add_9[0][0]']
#
# ==================================================================================================
# Total params: 5,666,387
# Trainable params: 4,460,883
# Non-trainable params: 1,205,504
# __________________________________________________________________________________________________

# %% [markdown]
# # training

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# define callbacks lists
model_checkpoint_callback = ModelCheckpoint(
  filepath='best_weights.h5',
  monitor='loss', 
  verbose=0, 
  save_best_only=True, 
  mode='min')
learning_rate_reduction = ReduceLROnPlateau(monitor='loss', 
                                          patience=2, 
                                          verbose=1, 
                                          factor=0.5, 
                                          min_lr=0.00001)
es = EarlyStopping(monitor="loss", mode="min", verbose=1, patience=10)
callbacks_list = [model_checkpoint_callback, learning_rate_reduction,es]

# %%
import math
def step_decay(epoch, initial_lr, drop, epochs_drop):
    lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lr
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
def get_callbacks():
    initial_lr = 0.001
    lr_schedule = LearningRateScheduler(lambda epoch: step_decay(epoch, initial_lr, 0.5, 10))
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
    checkpoint = ModelCheckpoint('best_weights.h5', monitor='val_accuracy', save_best_only=True, mode='max')
    return [lr_schedule, early_stopping, checkpoint]

# %%
callbacks = get_callbacks()

# %%
#  first generator here with this model....
history = model.fit_generator(generator=train_generator,epochs= 200,validation_data=val_generator,callbacks=callbacks,verbose=1)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 829s 146s/step - loss: 1.6016 - accuracy: 0.2000 - val_loss: 0.9939 - val_accuracy: 0.1719 - lr: 0.0010
# Epoch 2/200
# 5/5 [==============================] - 546s 114s/step - loss: 1.5775 - accuracy: 0.2875 - val_loss: 0.9893 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 3/200
# 5/5 [==============================] - 544s 114s/step - loss: 1.5580 - accuracy: 0.2625 - val_loss: 0.9882 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 4/200
# 5/5 [==============================] - 529s 111s/step - loss: 1.5452 - accuracy: 0.2625 - val_loss: 0.9927 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/200
# 5/5 [==============================] - 529s 110s/step - loss: 1.5300 - accuracy: 0.3750 - val_loss: 0.9959 - val_accuracy: 0.4844 - lr: 0.0010
# Epoch 6/200
# 5/5 [==============================] - 532s 111s/step - loss: 1.5033 - accuracy: 0.4500 - val_loss: 0.9893 - val_accuracy: 0.4531 - lr: 0.0010
# Epoch 7/200
# 5/5 [==============================] - 532s 111s/step - loss: 1.4536 - accuracy: 0.4812 - val_loss: 0.9982 - val_accuracy: 0.4375 - lr: 0.0010
# Epoch 8/200
# 5/5 [==============================] - 521s 109s/step - loss: 1.3886 - accuracy: 0.5437 - val_loss: 0.9948 - val_accuracy: 0.2188 - lr: 0.0010
# Epoch 9/200
# 5/5 [==============================] - 532s 112s/step - loss: 1.2913 - accuracy: 0.5188 - val_loss: 1.0800 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 10/200
# 5/5 [==============================] - 527s 111s/step - loss: 1.1959 - accuracy: 0.5312 - val_loss: 1.0342 - val_accuracy: 0.1562 - lr: 5.0000e-04
# Epoch 11/200
# 5/5 [==============================] - 532s 111s/step - loss: 1.0914 - accuracy: 0.6062 - val_loss: 1.0476 - val_accuracy: 0.1875 - lr: 5.0000e-04
# Epoch 12/200
# 5/5 [==============================] - 530s 111s/step - loss: 0.9805 - accuracy: 0.6500 - val_loss: 1.0432 - val_accuracy: 0.2031 - lr: 5.0000e-04
# Epoch 13/200
# 5/5 [==============================] - ETA: 0s - loss: 0.8918 - accuracy: 0.7312  Restoring model weights from the end of the best epoch: 3.
# 5/5 [==============================] - 526s 110s/step - loss: 0.8918 - accuracy: 0.7312 - val_loss: 1.0719 - val_accuracy: 0.3750 - lr: 5.0000e-04
# Epoch 13: early stopping

# %%
# Plot the loss and accuracy curves for training and validation 
fig, ax = plt.subplots(2,1)
fig.suptitle("Loss and Accuracy")
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='orange', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='orange',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)
